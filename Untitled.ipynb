# %% [markdown]
# <a href="https://colab.research.google.com/github/MiNA2026MW/demo-repository/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/Shareddrives/MINA proboszcza jak zobaczy pusta koperte/bd_lab2.sql'

try:
    with open(file_path, 'r') as f:
        content = f.read()
    print(content)
except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# --Zad 1
# --a) Wyjaśnić działanie operatora WHERE (RowNumber > 51) AND (RowNumber < 100).
#
# --WHERE (RowNumber > 51) AND (RowNumber < 100) filtruje wyniki zapytania, pozostawiając tylko te wiersze, którym funkcja Row_Number() przypisała numery od 52 do 99.
#
#
# -- Skrypt Lab2.01
# SELECT Row_Number() OVER (ORDER BY [LastName]) AS RowNumber
# ,[BusinessEntityID]
# ,[FirstName]
# ,[LastName]
# FROM [Person].[Person]
#
#
# --b) Zrealizować ( "stronicowanie" ):
#
#     Użyć tabeli temporary, wykorzystać INSERT from SELECT i odpytać tabelę temporary,
#     Wykorzystać wyrażenie CTE.
#
# -- Temp tabela
# CREATE TABLE #TempPerson (
#     RowNumber INT,
#     BusinessEntityID INT,
#     FirstName NVARCHAR(50),
#     LastName NVARCHAR(50)
# );
#
# INSERT INTO #TempPerson (RowNumber, BusinessEntityID, FirstName, LastName)
# SELECT
#     ROW_NUMBER() OVER (ORDER BY LastName) AS RowNumber,
#     BusinessEntityID,
#     FirstName,
#     LastName
# FROM Person.Person;
#
# SELECT *
# ...
